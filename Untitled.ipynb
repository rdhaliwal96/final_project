# %%
import pandas as pd

# %%
csv_path = "gun-violence-data_01-2013_03-2018.csv"
gun_df = pd.read_csv(csv_path)
gun_df.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# ...

# %%
state_df = gun_df.sort_values("state")
state_df.head()
# Out:
#         incident_id        date    state city_or_county  \
# 107927       486693  2016-01-15  Alabama     Birmingham
# 31449        183285  2014-08-13  Alabama  Muscle Shoals
# 7955         111667  2014-03-03  Alabama        Madison
# 162607       730697  2016-12-21  Alabama       Saraland
# 31438        174931  2014-08-13  Alabama     Huntsville
#
#                              address  n_killed  n_injured  \
# 107927            1140 Pratt Highway         0          1
# 31449           600 Firestone Avenue         1          1
# 7955                 7850 Highway 72         0          0
# 162607      1118 Martha Alleyn Drive         1          1
# 31438   3100 block of Gayhart Drive          0          0
#
#                                              incident_url  \
# 107927  http://www.gunviolencearchive.org/incident/486693
# 31449   http://www.gunviolencearchive.org/incident/183285
# 7955    http://www.gunviolencearchive.org/incident/111667
# ...

# %%
n_killed = gun_df.sort_values("n_killed", ascending=False)
n_killed.head()
# Out:
#         incident_id        date                 state  \
# 130448       577157  2016-06-12               Florida
# 217151       980577  2017-11-05                 Texas
# 232745      1049217  2018-02-14               Florida
# 101531       456893  2015-12-02            California
# 194          480366  2013-09-16  District of Columbia
#
#                   city_or_county                     address  n_killed  \
# 130448                   Orlando        1912 S Orange Avenue        50
# 217151        Sutherland Springs                  216 4th St        27
# 232745  Pompano Beach (Parkland)         5901 Pine Island Rd        17
# 101531            San Bernardino  1365 South Waterman Avenue        16
# 194         Washington Navy Yard         1336 Isaac Hull Ave        11
#
#         n_injured                                       incident_url  \
# 130448         53  http://www.gunviolencearchive.org/incident/577157
# 217151         20  http://www.gunviolencearchive.org/incident/980577
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
# Labels for the sections of our pie chart
labels = ["n_killed" ,"n_injured"]

# The values of each section of the pie chart
sizes = [220, 95]

# The colors of each section of the pie chart
colors = ["red", "orange"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0.2, 0.1)

# %%
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# ([<matplotlib.patches.Wedge at 0x255fb200668>,
# ...
#  [Text(-0.097149,-1.29636,'n_killed'), Text(0.0896759,1.19664,'n_injured')],
#  [Text(-0.059784,-0.797763,'69.8%'), Text(0.052311,0.698043,'30.2%')])

# %%
n_killed.count()
# Out:
# incident_id                    239677
# date                           239677
# state                          239677
# city_or_county                 239677
# address                        223180
# n_killed                       239677
# n_injured                      239677
# incident_url                   239677
# source_url                     239209
# incident_url_fields_missing    239677
# congressional_district         227733
# gun_stolen                     140179
# gun_type                       140226
# incident_characteristics       239351
# latitude                       231754
# location_description            42089
# longitude                      231754
# n_guns_involved                140226
# notes                          158660
# participant_age                147379
# participant_age_group          197558
# participant_gender             203315
# participant_name               117424
# participant_relationship        15774
# participant_status             212051
# ...

# %%
n_killed.dropna(how = 'any')
# Out:
#         incident_id        date           state  \
# 36           482856  2013-03-13        New York
# 191341       859875  2017-06-05         Florida
# 165585       743995  2017-01-06         Florida
# 124198       552393  2016-05-03         Florida
# 181          492276  2013-08-25         Florida
# 192815       866933  2017-06-14      California
# 198060       889758  2017-07-13  South Carolina
# 226949      1022547  2018-01-08           Texas
# 236201      1065908  2018-03-09      California
# 171024       771826  2017-02-09     Mississippi
# 237046      1069080  2018-03-14        New York
# 136987       610379  2016-07-23           Texas
# 53370        276613  2015-01-10           Idaho
# 180121       812491  2017-04-05         Florida
# 138250       616948  2016-07-30      Washington
# 127993       566863  2016-05-27        New York
# 236400      1066875  2018-03-10         Florida
# 217298       981330  2017-11-05      California
# ...

# %%
n_killed.count()
# Out:
# incident_id                    239677
# date                           239677
# state                          239677
# city_or_county                 239677
# address                        223180
# n_killed                       239677
# n_injured                      239677
# incident_url                   239677
# source_url                     239209
# incident_url_fields_missing    239677
# congressional_district         227733
# gun_stolen                     140179
# gun_type                       140226
# incident_characteristics       239351
# latitude                       231754
# location_description            42089
# longitude                      231754
# n_guns_involved                140226
# notes                          158660
# participant_age                147379
# participant_age_group          197558
# participant_gender             203315
# participant_name               117424
# participant_relationship        15774
# participant_status             212051
# ...

# %%
n_killed.describe()
# Out:
#         incident_id       n_killed      n_injured  congressional_district  \
# count  2.396770e+05  239677.000000  239677.000000           227733.000000
# mean   5.593343e+05       0.252290       0.494007                8.001265
# std    2.931287e+05       0.521779       0.729952                8.480835
# min    9.211400e+04       0.000000       0.000000                0.000000
# 25%    3.085450e+05       0.000000       0.000000                2.000000
# 50%    5.435870e+05       0.000000       0.000000                5.000000
# 75%    8.172280e+05       0.000000       1.000000               10.000000
# max    1.083472e+06      50.000000      53.000000               53.000000
#
#             latitude      longitude  n_guns_involved  state_house_district  \
# count  231754.000000  231754.000000    140226.000000         200905.000000
# mean       37.546598     -89.338348         1.372442             55.447132
# std         5.130763      14.359546         4.678202             42.048117
# ...

# %%
n_killed.dropna(subset=['participant_age'], inplace=True)
n_killed.count()
# Out:
# incident_id                    147379
# date                           147379
# state                          147379
# city_or_county                 147379
# address                        136647
# n_killed                       147379
# n_injured                      147379
# incident_url                   147379
# source_url                     147041
# incident_url_fields_missing    147379
# congressional_district         139054
# gun_stolen                      91173
# gun_type                        91195
# incident_characteristics       147217
# latitude                       141348
# location_description            25893
# longitude                      141348
# n_guns_involved                 91195
# notes                          100903
# participant_age                147379
# participant_age_group          147183
# participant_gender             146168
# participant_name               108030
# participant_relationship        12620
# participant_status             146927
# ...

# %%
n_killed.dropna(subset=['latitude', 'longitude'])
# Out:
#         incident_id        date                 state  \
# 130448       577157  2016-06-12               Florida
# 217151       980577  2017-11-05                 Texas
# 232745      1049217  2018-02-14               Florida
# 101531       456893  2015-12-02            California
# 194          480366  2013-09-16  District of Columbia
# 92624        423223  2015-10-01                Oregon
# 207904       930569  2017-09-10                 Texas
# 75530        359830  2015-06-17        South Carolina
# 70511        341622  2015-05-17                 Texas
# 83911        390526  2015-08-08                 Texas
# 58843        298122  2015-02-26              Missouri
# 37527        192851  2014-09-18               Florida
# 122526       545525  2016-04-22                  Ohio
# 189720       853756  2017-05-27           Mississippi
# 151          491265  2013-07-26               Florida
# 49958        263556  2014-12-15          Pennsylvania
# ...

# %%
n_killed.count()
# Out:
# incident_id                    147379
# date                           147379
# state                          147379
# city_or_county                 147379
# address                        136647
# n_killed                       147379
# n_injured                      147379
# incident_url                   147379
# source_url                     147041
# incident_url_fields_missing    147379
# congressional_district         139054
# gun_stolen                      91173
# gun_type                        91195
# incident_characteristics       147217
# latitude                       141348
# location_description            25893
# longitude                      141348
# n_guns_involved                 91195
# notes                          100903
# participant_age                147379
# participant_age_group          147183
# participant_gender             146168
# participant_name               108030
# participant_relationship        12620
# participant_status             146927
# ...

# %%
n_killed.to_csv("out.csv", index=False)
